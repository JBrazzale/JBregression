# %% [markdown]
# ## Feature Engineering
#
# This is my df that I have scraped from Boxofficemojo. I chose to scrape the top 200 (domestic) movies from 2010-2021. Any titles with "re-release" were omitted from my scrape. My initial database had 2200 titles in it, many of them had missing or null values.
#
# The initial part of my cleaning process took place in DBbrowser, I performed the following:
#
# - All columns with multiple null values were removed in DBbrowser
#
# - I also chose to group the dates into their respective quarters.
#       Q1:JAN-MAR  Q2:APR-JUN  Q3:JUL-SEP  Q4:OCT-DEC
# - Removed all movies with a budget below 10M
#
# After performing the initial cleaning, we can see that I have 1195 columns remaining.
#
# There are still a few issues with this dataframe that need to be addressed before modeling:
#
# - Some of the titles have duplicate entries
#
# - All of my monetary figures are listed as string objects, they also have commas and a dollar sign attached
#
# - Runtime is also a string object, with "hr" and "min" attached. changing these to ints and getting a sum in minutes will make them easier to handle.
#
# - MPAA rating is a categorical feature, I am planning on fixing this by using dummy variables.
#
# - There are many problems associated with my Genre column, a full overview of these problems can be seen below

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns 
import numpy as np 
import warnings 
warnings.filterwarnings('ignore')

base_df = pd.read_csv('final_boxoffice_data_qdates.csv')

# %%
base_df.head(5) #checking to see if everything is here, we can see that our revenue columns still contain $ and commas
# Out:
#               Title Domestic_Revenue Worldwide_Revenue  \
# 0  12 Years a Slave      $56,671,993      $187,733,202
# 1         127 Hours      $18,335,230       $60,738,797
# 2          13 Hours      $52,853,219       $69,411,370
# 3              1917     $159,227,644      $384,983,987
# 4            2 Guns      $75,612,460      $131,940,411
#
#                 Distributor Opening_weekend_box  no_Theaters_open  \
# 0  Fox Searchlight Pictures            $923,715                19
# 1  Fox Searchlight Pictures            $264,851                 4
# 2        Paramount Pictures         $16,194,738              2389
# 3        Universal Pictures            $576,216                11
# 4        Universal Pictures         $27,059,130              3025
#
#         Budget  Release Quarter MPAA_Rating     Run_Time  \
# 0  $20,000,000                4           R  2 hr 14 min
# 1  $18,000,000                4           R  1 hr 34 min
# 2  $50,000,000                1           R  2 hr 24 min
# 3  $95,000,000                4           R  1 hr 59 min
# 4  $61,000,000                3           R  1 hr 49 min
#
#                           Genre  Days_In_theaters
# 0       Biography,Drama,History               440
# 1               Biography,Drama               422
# 2     Action,Drama,Thriller,War               352
# 3              Action,Drama,War               373
# 4  Action,Comedy,Crime,Thriller               152

# %%
base_df.info()#note that our revenue columns are listed as objects instead of ints
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195 entries, 0 to 1194
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                1195 non-null   object
#  1   Domestic_Revenue     1195 non-null   object
#  2   Worldwide_Revenue    1195 non-null   object
#  3   Distributor          1195 non-null   object
#  4   Opening_weekend_box  1195 non-null   object
#  5   no_Theaters_open     1195 non-null   int64
#  6   Budget               1195 non-null   object
#  7   Release Quarter      1195 non-null   int64
#  8   MPAA_Rating          1195 non-null   object
#  9   Run_Time             1195 non-null   object
#  10  Genre                1195 non-null   object
#  11  Days_In_theaters     1195 non-null   int64
# dtypes: int64(3), object(9)
# memory usage: 112.2+ KB

# %%
base_df.shape #checking to see the total number of movies represented by our rows
# Out:
# (1195, 12)

# %%
base_df[base_df.columns[1:3]] = base_df[base_df.columns[1:3]].replace('[\$,]', '', regex=True).astype(int)
base_df[base_df.columns[4:7]] = base_df[base_df.columns[4:7]].replace('[\$,]', '', regex=True).astype(int)
#this will strip the dollar signs and commas, as well as turn our strings into integer values

# %%
base_df.head()#quick check to see if this worked
# Out:
#               Title  Domestic_Revenue  Worldwide_Revenue  \
# 0  12 Years a Slave          56671993          187733202
# 1         127 Hours          18335230           60738797
# 2          13 Hours          52853219           69411370
# 3              1917         159227644          384983987
# 4            2 Guns          75612460          131940411
#
#                 Distributor  Opening_weekend_box  no_Theaters_open    Budget  \
# 0  Fox Searchlight Pictures               923715                19  20000000
# 1  Fox Searchlight Pictures               264851                 4  18000000
# 2        Paramount Pictures             16194738              2389  50000000
# 3        Universal Pictures               576216                11  95000000
# 4        Universal Pictures             27059130              3025  61000000
#
#    Release Quarter MPAA_Rating     Run_Time                         Genre  \
# 0                4           R  2 hr 14 min       Biography,Drama,History
# 1                4           R  1 hr 34 min               Biography,Drama
# 2                1           R  2 hr 24 min     Action,Drama,Thriller,War
# 3                4           R  1 hr 59 min              Action,Drama,War
# 4                3           R  1 hr 49 min  Action,Comedy,Crime,Thriller
#
#    Days_In_theaters
# 0               440
# 1               422
# 2               352
# 3               373
# 4               152

# %%
df_2 = base_df.drop_duplicates('Title') # I noticed in SQL that there were duplicate titles, this should drop the extras

# %%
df_2.shape #quick check again, looks like it dropped 39 titles
# Out:
# (1156, 12)

# %%
#runtime is currently listed as a string object, it also has 'hr' and 'min' still attached, lets strip those and 
#combine in a new column. Also, if anyone is reading this, please let me know if there is an easier way to do this
#I spent way too long on it. lol
df_2['hour'] = (df_2['Run_Time'].astype(str).str[0]).astype(int)
df_2['min'] = np.where(df_2['Run_Time'].str.contains('min'), ((df_2['Run_Time'].astype(str).str[5:]).str.replace('min', '')), 0).astype(int)
df_2['Running_Time(min)'] = (df_2['hour'].astype(int)*60)+df_2['min']

# I don't want to keep these new columns. I also have no need for my original Run_Time
del df_2['hour']
del df_2['min']
del df_2['Run_Time']

#this kicked back a warning, since everything is still functional I decided to mute it

# %%
df_2.head() #We're getting there!
# Out:
#               Title  Domestic_Revenue  Worldwide_Revenue  \
# 0  12 Years a Slave          56671993          187733202
# 1         127 Hours          18335230           60738797
# 2          13 Hours          52853219           69411370
# 3              1917         159227644          384983987
# 4            2 Guns          75612460          131940411
#
#                 Distributor  Opening_weekend_box  no_Theaters_open    Budget  \
# 0  Fox Searchlight Pictures               923715                19  20000000
# 1  Fox Searchlight Pictures               264851                 4  18000000
# 2        Paramount Pictures             16194738              2389  50000000
# 3        Universal Pictures               576216                11  95000000
# 4        Universal Pictures             27059130              3025  61000000
#
#    Release Quarter MPAA_Rating                         Genre  \
# 0                4           R       Biography,Drama,History
# 1                4           R               Biography,Drama
# 2                1           R     Action,Drama,Thriller,War
# 3                4           R              Action,Drama,War
# 4                3           R  Action,Comedy,Crime,Thriller
#
#    Days_In_theaters  Running_Time(min)
# 0               440                134
# 1               422                 94
# 2               352                144
# 3               373                119
# 4               152                109

# %%
#now we just have to assign dummy vars to our MPAA Rating

df_2 = pd.concat([df_2.drop('MPAA_Rating', axis=1), pd.get_dummies(df_2['MPAA_Rating'])], axis=1)

#I don't want the dash in PG-13 
df_2 = df_2.rename(columns = {'PG-13':'PG_13'})

# %%
#I also discovered release date did not work well with a numeric representation of quarter, so i changed them to dummies
df_2 = pd.concat([df_2.drop('Release Quarter', axis=1), pd.get_dummies(df_2['Release Quarter'])], axis=1)

#I don't want the dash in PG-13 
df_2 = df_2.rename(columns = {1 :'winter', 2 : 'spring', 3 : 'summer', 4 : 'fall_holiday'})

# %%
df_2.head()
# Out:
#               Title  Domestic_Revenue  Worldwide_Revenue  \
# 0  12 Years a Slave          56671993          187733202
# 1         127 Hours          18335230           60738797
# 2          13 Hours          52853219           69411370
# 3              1917         159227644          384983987
# 4            2 Guns          75612460          131940411
#
#                 Distributor  Opening_weekend_box  no_Theaters_open    Budget  \
# 0  Fox Searchlight Pictures               923715                19  20000000
# 1  Fox Searchlight Pictures               264851                 4  18000000
# 2        Paramount Pictures             16194738              2389  50000000
# 3        Universal Pictures               576216                11  95000000
# 4        Universal Pictures             27059130              3025  61000000
#
#                           Genre  Days_In_theaters  Running_Time(min)  G  PG  \
# 0       Biography,Drama,History               440                134  0   0
# 1               Biography,Drama               422                 94  0   0
# 2     Action,Drama,Thriller,War               352                144  0   0
# 3              Action,Drama,War               373                119  0   0
# 4  Action,Comedy,Crime,Thriller               152                109  0   0
#
#    PG_13  R  winter  spring  summer  fall_holiday
# 0      0  1       0       0       0             1
# 1      0  1       0       0       0             1
# 2      0  1       1       0       0             0
# 3      0  1       0       0       0             1
# 4      0  1       0       0       1             0

# %% [markdown]
# ## The Genre Problem
# Although I originally intended for Genre to be one of my final features, I have run into a few issues with it.
# Boxofficemojo allows for multiple genre assignment for each film. This allows for a very high number of unique
# genre combinations for each movie. Some films have as many as 10 genres attached to their page. When I tried to assign a numeric value for genres, the values ranged from 0-400 with very few movies sharing a unique id. When
# I visualized this in a scatter plot, the result was too random. Since my deadline is approaching, I have decided
# to omit genre from my final targets.

# %%
#The Genre Column is looking like it might be a bit tricky as there are multiple categorical values with commas 
#separating them
genres = np.unique(', '.join(df_2['Genre']).split(', '))#this will separate out our unique combinations of genres, lets encode each one with a number
genres
# Out:
# array(['Action',
#        'Action,Adventure,Animation,Comedy,Crime,Family,Fantasy,Romance,Sci-Fi',
#        'Action,Adventure,Animation,Comedy,Crime,Family,Romance,Sci-Fi,Thriller',
#        'Action,Adventure,Animation,Comedy,Drama,Family,Fantasy',
#        'Action,Adventure,Animation,Comedy,Drama,Family,Fantasy,Romance',
#        'Action,Adventure,Animation,Comedy,Drama,Family,Sci-Fi',
#        'Action,Adventure,Animation,Comedy,Family',
#        'Action,Adventure,Animation,Comedy,Family,Fantasy',
#        'Action,Adventure,Animation,Comedy,Family,Fantasy,Musical,Sci-Fi',
#        'Action,Adventure,Animation,Comedy,Family,Sci-Fi',
#        'Action,Adventure,Animation,Drama,Family,Fantasy',
#        'Action,Adventure,Animation,Family,Fantasy',
#        'Action,Adventure,Animation,Family,Fantasy,Mystery,Thriller,War',
#        'Action,Adventure,Animation,Family,Fantasy,Sci-Fi',
#        'Action,Adventure,Animation,Family,Sci-Fi',
#        'Action,Adventure,Biography,Drama',
#        'Action,Adventure,Biography,Drama,History',
#        'Action,Adventure,Biography,Drama,Romance,Thriller',
#        'Action,Adventure,Biography,Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Adventure,Comedy,Crime',
#        'Action,Adventure,Comedy,Crime,Fantasy,Sci-Fi',
#        'Action,Adventure,Comedy,Crime,Mystery',
#        'Action,Adventure,Comedy,Crime,Thriller',
#        'Action,Adventure,Comedy,Drama,Family,Fantasy',
#        'Action,Adventure,Comedy,Family,Fantasy,Sci-Fi',
#        'Action,Adventure,Comedy,Family,Fantasy,Thriller',
#        'Action,Adventure,Comedy,Family,Mystery,Sci-Fi',
#        'Action,Adventure,Comedy,Fantasy',
#        'Action,Adventure,Comedy,Fantasy,Sci-Fi',
#        'Action,Adventure,Comedy,Sci-Fi',
#        'Action,Adventure,Comedy,Thriller',
#        'Action,Adventure,Crime,Drama,Mystery,Thriller',
#        'Action,Adventure,Crime,Drama,Thriller',
#        'Action,Adventure,Crime,Mystery,Thriller',
#        'Action,Adventure,Crime,Sport,Thriller',
#        'Action,Adventure,Crime,Thriller', 'Action,Adventure,Drama',
#        'Action,Adventure,Drama,Fantasy',
#        'Action,Adventure,Drama,Fantasy,History,Romance',
#        'Action,Adventure,Drama,Fantasy,Romance',
#        'Action,Adventure,Drama,Fantasy,Romance,Thriller',
#        'Action,Adventure,Drama,History',
#        'Action,Adventure,Drama,History,War',
#        'Action,Adventure,Drama,History,Western',
#        'Action,Adventure,Drama,Romance,Sci-Fi,Thriller',
#        'Action,Adventure,Drama,Romance,Thriller',
#        'Action,Adventure,Drama,Sci-Fi',
#        'Action,Adventure,Drama,Sci-Fi,Thriller',
#        'Action,Adventure,Drama,Thriller',
#        'Action,Adventure,Family,Fantasy',
#        'Action,Adventure,Family,Fantasy,Musical,Romance',
#        'Action,Adventure,Family,Fantasy,Mystery,Sci-Fi',
#        'Action,Adventure,Family,Fantasy,Romance',
#        'Action,Adventure,Fantasy',
#        'Action,Adventure,Fantasy,History,Romance,Thriller',
#        'Action,Adventure,Fantasy,Horror,Mystery',
#        'Action,Adventure,Fantasy,Horror,Mystery,Romance',
#        'Action,Adventure,Fantasy,Horror,Mystery,Thriller',
#        'Action,Adventure,Fantasy,Horror,Sci-Fi',
#        'Action,Adventure,Fantasy,Horror,Sci-Fi,Thriller',
#        'Action,Adventure,Fantasy,Horror,Thriller',
#        'Action,Adventure,Fantasy,Sci-Fi',
#        'Action,Adventure,Fantasy,Sci-Fi,War',
#        'Action,Adventure,Fantasy,Sci-Fi,Western',
#        'Action,Adventure,Fantasy,Thriller',
#        'Action,Adventure,Fantasy,War',
#        'Action,Adventure,Horror,Mystery,Sci-Fi,Thriller',
#        'Action,Adventure,Horror,Sci-Fi',
#        'Action,Adventure,Horror,Sci-Fi,Thriller',
#        'Action,Adventure,Mystery', 'Action,Adventure,Mystery,Sci-Fi',
#        'Action,Adventure,Sci-Fi', 'Action,Adventure,Sci-Fi,Thriller',
#        'Action,Adventure,Thriller', 'Action,Adventure,Thriller,War',
#        'Action,Adventure,Western',
#        'Action,Animation,Comedy,Crime,Family,Fantasy,Sci-Fi',
#        'Action,Animation,Comedy,Family,Fantasy,Sci-Fi',
#        'Action,Biography,Drama', 'Action,Biography,Drama,History',
#        'Action,Biography,Drama,History,War,Western',
#        'Action,Biography,Drama,Sport', 'Action,Biography,Drama,Sport,War',
#        'Action,Biography,Drama,War', 'Action,Comedy',
#        'Action,Comedy,Crime', 'Action,Comedy,Crime,Drama',
#        'Action,Comedy,Crime,Drama,Thriller', 'Action,Comedy,Crime,Family',
#        'Action,Comedy,Crime,Fantasy,Mystery,Thriller',
#        'Action,Comedy,Crime,Thriller', 'Action,Comedy,Documentary',
#        'Action,Comedy,Family', 'Action,Comedy,Fantasy,Horror,Romance',
#        'Action,Comedy,Fantasy,Romance', 'Action,Comedy,Fantasy,Sci-Fi',
#        'Action,Comedy,Horror', 'Action,Comedy,Horror,Mystery,Thriller',
#        'Action,Comedy,Romance', 'Action,Comedy,Romance,Thriller',
#        'Action,Crime,Drama', 'Action,Crime,Drama,History,Thriller',
#        'Action,Crime,Drama,Music,Thriller',
#        'Action,Crime,Drama,Mystery,Thriller',
#        'Action,Crime,Drama,Romance,Thriller',
#        'Action,Crime,Drama,Sci-Fi,Thriller', 'Action,Crime,Drama,Sport',
#        'Action,Crime,Drama,Thriller',
#        'Action,Crime,Drama,Thriller,Western',
#        'Action,Crime,Mystery,Thriller', 'Action,Crime,Sci-Fi',
#        'Action,Crime,Sci-Fi,Thriller', 'Action,Crime,Thriller',
#        'Action,Drama', 'Action,Drama,Family,Sport',
#        'Action,Drama,Fantasy', 'Action,Drama,Fantasy,Horror,War',
#        'Action,Drama,Fantasy,Romance',
#        'Action,Drama,Fantasy,Thriller,Western',
#        'Action,Drama,History,Mystery', 'Action,Drama,History,Thriller',
#        'Action,Drama,History,Thriller,War', 'Action,Drama,History,War',
#        'Action,Drama,Horror,Thriller',
#        'Action,Drama,Mystery,Sci-Fi,Thriller',
#        'Action,Drama,Mystery,Thriller',
#        'Action,Drama,Romance,Thriller,War', 'Action,Drama,Sci-Fi',
#        'Action,Drama,Sci-Fi,Thriller', 'Action,Drama,Sport',
#        'Action,Drama,Thriller', 'Action,Drama,Thriller,War',
#        'Action,Drama,War', 'Action,Fantasy,Horror',
#        'Action,Fantasy,Horror,Sci-Fi', 'Action,Fantasy,Sci-Fi',
#        'Action,Fantasy,Sci-Fi,Thriller', 'Action,Fantasy,Thriller',
#        'Action,Fantasy,Western', 'Action,Horror,Sci-Fi',
#        'Action,Horror,Sci-Fi,Thriller', 'Action,Horror,Sci-Fi,War',
#        'Action,Horror,Thriller', 'Action,Mystery,Sci-Fi,Thriller',
#        'Action,Mystery,Thriller', 'Action,Sci-Fi',
#        'Action,Sci-Fi,Thriller', 'Action,Sci-Fi,Thriller,Western',
#        'Action,Thriller', 'Adventure,Animation,Comedy,Crime,Drama,Family',
#        'Adventure,Animation,Comedy,Crime,Drama,Family,Musical',
#        'Adventure,Animation,Comedy,Crime,Drama,Family,Western',
#        'Adventure,Animation,Comedy,Crime,Family',
#        'Adventure,Animation,Comedy,Crime,Family,Sci-Fi',
#        'Adventure,Animation,Comedy,Documentary,Family',
#        'Adventure,Animation,Comedy,Drama,Family',
#        'Adventure,Animation,Comedy,Drama,Family,Fantasy',
#        'Adventure,Animation,Comedy,Drama,Family,Fantasy,Horror,Romance',
#        'Adventure,Animation,Comedy,Drama,Family,Fantasy,Musical',
#        'Adventure,Animation,Comedy,Drama,Family,Fantasy,Sci-Fi',
#        'Adventure,Animation,Comedy,Drama,Family,Sci-Fi',
#        'Adventure,Animation,Comedy,Family',
#        'Adventure,Animation,Comedy,Family,Fantasy',
#        'Adventure,Animation,Comedy,Family,Fantasy,Horror',
#        'Adventure,Animation,Comedy,Family,Fantasy,Horror,Romance',
#        'Adventure,Animation,Comedy,Family,Fantasy,Music',
#        'Adventure,Animation,Comedy,Family,Fantasy,Music,Musical',
#        'Adventure,Animation,Comedy,Family,Fantasy,Musical',
#        'Adventure,Animation,Comedy,Family,Fantasy,Musical,Romance',
#        'Adventure,Animation,Comedy,Family,Fantasy,Mystery',
#        'Adventure,Animation,Comedy,Family,Fantasy,Mystery,Romance',
#        'Adventure,Animation,Comedy,Family,Fantasy,Romance',
#        'Adventure,Animation,Comedy,Family,Fantasy,Sci-Fi',
#        'Adventure,Animation,Comedy,Family,Musical',
#        'Adventure,Animation,Comedy,Family,Romance,Sci-Fi',
#        'Adventure,Animation,Comedy,Family,Sci-Fi',
#        'Adventure,Animation,Comedy,Family,Sport',
#        'Adventure,Animation,Comedy,Fantasy',
#        'Adventure,Animation,Drama,Family,Musical',
#        'Adventure,Animation,Family,Fantasy,Musical',
#        'Adventure,Biography,Crime,Drama,Thriller',
#        'Adventure,Biography,Drama,History', 'Adventure,Comedy',
#        'Adventure,Comedy,Crime', 'Adventure,Comedy,Crime,Drama',
#        'Adventure,Comedy,Crime,Family,Musical,Mystery',
#        'Adventure,Comedy,Drama', 'Adventure,Comedy,Drama,Family,Fantasy',
#        'Adventure,Comedy,Drama,Fantasy,Musical',
#        'Adventure,Comedy,Drama,Fantasy,Romance',
#        'Adventure,Comedy,Drama,Romance',
#        'Adventure,Comedy,Drama,Romance,Sci-Fi',
#        'Adventure,Comedy,Family,Fantasy',
#        'Adventure,Comedy,Family,Fantasy,Horror',
#        'Adventure,Comedy,Family,Musical',
#        'Adventure,Comedy,Family,Mystery',
#        'Adventure,Comedy,Family,Romance',
#        'Adventure,Comedy,Fantasy,Mystery',
#        'Adventure,Comedy,Fantasy,Romance', 'Adventure,Comedy,Sci-Fi',
#        'Adventure,Drama,Family',
#        'Adventure,Drama,Family,Fantasy,Thriller',
#        'Adventure,Drama,Family,War', 'Adventure,Drama,Fantasy',
#        'Adventure,Drama,Fantasy,Romance',
#        'Adventure,Drama,Fantasy,Romance,Thriller',
#        'Adventure,Drama,History',
#        'Adventure,Drama,Horror,Mystery,Sci-Fi,Thriller',
#        'Adventure,Drama,Horror,Thriller',
#        'Adventure,Drama,Mystery,Sci-Fi,Thriller',
#        'Adventure,Drama,Sci-Fi', 'Adventure,Drama,Sci-Fi,Thriller',
#        'Adventure,Family,Fantasy', 'Adventure,Family,Fantasy,Musical',
#        'Adventure,Family,Fantasy,Thriller', 'Adventure,Family,Sci-Fi',
#        'Adventure,Horror', 'Adventure,Horror,Mystery',
#        'Adventure,Mystery,Sci-Fi', 'Animation,Comedy,Drama,Romance',
#        'Animation,Comedy,Family', 'Animation,Comedy,Family,Horror,Sci-Fi',
#        'Animation,Comedy,Family,Musical', 'Animation,Drama,Fantasy',
#        'Biography,Comedy,Crime,Drama', 'Biography,Comedy,Drama',
#        'Biography,Comedy,Drama,Family,History,Sport',
#        'Biography,Comedy,Drama,History', 'Biography,Comedy,Drama,Music',
#        'Biography,Comedy,Drama,Sport', 'Biography,Comedy,Drama,War',
#        'Biography,Crime,Drama', 'Biography,Crime,Drama,History',
#        'Biography,Crime,Drama,Thriller', 'Biography,Drama',
#        'Biography,Drama,Family', 'Biography,Drama,Family,History,Sport',
#        'Biography,Drama,Family,Music', 'Biography,Drama,Family,Romance',
#        'Biography,Drama,Family,Sport', 'Biography,Drama,History',
#        'Biography,Drama,History,Music', 'Biography,Drama,History,Romance',
#        'Biography,Drama,History,Sport',
#        'Biography,Drama,History,Thriller,War',
#        'Biography,Drama,History,War', 'Biography,Drama,Music',
#        'Biography,Drama,Music,Musical', 'Biography,Drama,Music,Romance',
#        'Biography,Drama,Musical', 'Biography,Drama,Romance',
#        'Biography,Drama,Sport', 'Biography,Drama,Thriller',
#        'Biography,Drama,War', 'Comedy', 'Comedy,Crime',
#        'Comedy,Crime,Drama', 'Comedy,Crime,Drama,Mystery,Thriller',
#        'Comedy,Crime,Drama,Romance', 'Comedy,Crime,Mystery',
#        'Comedy,Crime,Mystery,Thriller', 'Comedy,Crime,Romance,Thriller',
#        'Comedy,Crime,Thriller', 'Comedy,Documentary', 'Comedy,Drama',
#        'Comedy,Drama,Family', 'Comedy,Drama,Family,Fantasy',
#        'Comedy,Drama,Family,Fantasy,Musical',
#        'Comedy,Drama,Family,Musical', 'Comedy,Drama,Family,Romance',
#        'Comedy,Drama,Fantasy,Horror', 'Comedy,Drama,Fantasy,Romance',
#        'Comedy,Drama,History,War', 'Comedy,Drama,Horror',
#        'Comedy,Drama,Music', 'Comedy,Drama,Music,Musical,Romance',
#        'Comedy,Drama,Music,Mystery', 'Comedy,Drama,Music,Romance',
#        'Comedy,Drama,Musical,Romance', 'Comedy,Drama,Romance',
#        'Comedy,Drama,Romance,Sport', 'Comedy,Drama,Sport',
#        'Comedy,Drama,Thriller', 'Comedy,Drama,War', 'Comedy,Family',
#        'Comedy,Family,Fantasy', 'Comedy,Family,Fantasy,Musical',
#        'Comedy,Family,Fantasy,Mystery,Sci-Fi',
#        'Comedy,Family,Fantasy,Romance', 'Comedy,Family,Fantasy,Sport',
#        'Comedy,Family,Fantasy,War', 'Comedy,Fantasy',
#        'Comedy,Fantasy,Horror', 'Comedy,Fantasy,Horror,Romance',
#        'Comedy,Fantasy,Music,Romance', 'Comedy,Fantasy,Musical,Romance',
#        'Comedy,Fantasy,Romance', 'Comedy,Horror',
#        'Comedy,Horror,Mystery,Sci-Fi,Thriller',
#        'Comedy,Horror,Mystery,Thriller', 'Comedy,Horror,Romance',
#        'Comedy,Music', 'Comedy,Music,Romance', 'Comedy,Musical,Romance',
#        'Comedy,Mystery,Sci-Fi', 'Comedy,Romance', 'Comedy,Sci-Fi',
#        'Comedy,Western', 'Crime,Documentary', 'Crime,Drama',
#        'Crime,Drama,Fantasy,Horror,Mystery,Thriller',
#        'Crime,Drama,History', 'Crime,Drama,History,Thriller',
#        'Crime,Drama,Horror,Mystery', 'Crime,Drama,Horror,Thriller',
#        'Crime,Drama,Mystery', 'Crime,Drama,Mystery,Thriller',
#        'Crime,Drama,Mystery,Thriller,Western', 'Crime,Drama,Romance',
#        'Crime,Drama,Sci-Fi', 'Crime,Drama,Thriller',
#        'Crime,Horror,Mystery', 'Crime,Horror,Mystery,Thriller',
#        'Crime,Horror,Thriller', 'Crime,Mystery,Thriller',
#        'Crime,Thriller', 'Documentary,History', 'Documentary,Music',
#        'Drama', 'Drama,Family', 'Drama,Family,Fantasy,Musical,Romance',
#        'Drama,Family,Music,Musical', 'Drama,Family,Sport',
#        'Drama,Fantasy', 'Drama,Fantasy,Horror',
#        'Drama,Fantasy,Horror,Mystery,Sci-Fi,Thriller',
#        'Drama,Fantasy,Horror,Mystery,Thriller',
#        'Drama,Fantasy,Horror,Thriller',
#        'Drama,Fantasy,Music,Romance,Sci-Fi',
#        'Drama,Fantasy,Mystery,Romance', 'Drama,Fantasy,Romance',
#        'Drama,Fantasy,Sci-Fi', 'Drama,Fantasy,Thriller',
#        'Drama,History,Mystery,Thriller', 'Drama,History,Thriller',
#        'Drama,History,Thriller,War', 'Drama,History,War', 'Drama,Horror',
#        'Drama,Horror,Mystery', 'Drama,Horror,Mystery,Romance',
#        'Drama,Horror,Mystery,Romance,Thriller',
#        'Drama,Horror,Mystery,Sci-Fi',
#        'Drama,Horror,Mystery,Sci-Fi,Thriller',
#        'Drama,Horror,Mystery,Thriller', 'Drama,Horror,Sci-Fi',
#        'Drama,Horror,Sci-Fi,Thriller', 'Drama,Horror,Thriller',
#        'Drama,Music', 'Drama,Music,Musical,Romance',
#        'Drama,Music,Romance', 'Drama,Musical,Romance', 'Drama,Mystery',
#        'Drama,Mystery,Romance,Thriller',
#        'Drama,Mystery,Romance,Thriller,War',
#        'Drama,Mystery,Sci-Fi,Thriller', 'Drama,Mystery,Thriller',
#        'Drama,Mystery,War', 'Drama,Romance', 'Drama,Romance,Sci-Fi',
#        'Drama,Romance,Sci-Fi,Thriller', 'Drama,Romance,Thriller',
#        'Drama,Romance,Western', 'Drama,Sci-Fi', 'Drama,Sci-Fi,Thriller',
#        'Drama,Sport', 'Drama,Thriller', 'Drama,Thriller,War',
#        'Drama,Western', 'Family,Fantasy,Musical,Romance',
#        'Fantasy,Horror', 'Fantasy,Horror,Mystery,Romance,Thriller',
#        'Fantasy,Horror,Mystery,Thriller', 'Fantasy,Horror,Thriller',
#        'Horror', 'Horror,Mystery', 'Horror,Mystery,Sci-Fi',
#        'Horror,Mystery,Sci-Fi,Thriller', 'Horror,Mystery,Thriller',
#        'Horror,Sci-Fi,Thriller', 'Horror,Thriller',
#        'Mystery,Sci-Fi,Thriller', 'Mystery,Thriller',
#        'Romance,Sci-Fi,Thriller', 'Sci-Fi,Thriller', 'Thriller'],
#       dtype='<U70')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
gle = LabelEncoder()
genre_labels = gle.fit_transform(df_2['Genre'])
genre_mappings = {index: label for index, label in 
                  enumerate(gle.classes_)}
#this will give each combination of genres its own unique numeric label
#there are currently too many combinations of genres.

# %%
df_2['Genre Label'] = genre_labels

# %%
df_2.columns #looks like we have a bit of trailing whitespace
# Out:
# Index(['Title', 'Domestic_Revenue', 'Worldwide_Revenue', 'Distributor',
#        'Opening_weekend_box', 'no_Theaters_open', 'Budget', 'Genre',
#        'Days_In_theaters', 'Running_Time(min)', 'G', 'PG', 'PG_13', 'R',
#        'winter', 'spring', 'summer', 'fall_holiday', 'Genre Label'],
#       dtype='object')

# %%
df_2.columns = df_2.columns.map(str.strip)
df_2.columns
# Out:
# Index(['Title', 'Domestic_Revenue', 'Worldwide_Revenue', 'Distributor',
#        'Opening_weekend_box', 'no_Theaters_open', 'Budget', 'Genre',
#        'Days_In_theaters', 'Running_Time(min)', 'G', 'PG', 'PG_13', 'R',
#        'winter', 'spring', 'summer', 'fall_holiday', 'Genre Label'],
#       dtype='object')

# %%
#lets save this so that we can work on it in our modeling folder
df_2
# Out:
#                        Title  Domestic_Revenue  Worldwide_Revenue  \
# 0           12 Years a Slave          56671993          187733202
# 1                  127 Hours          18335230           60738797
# 2                   13 Hours          52853219           69411370
# 3                       1917         159227644          384983987
# 4                     2 Guns          75612460          131940411
# ...                      ...               ...                ...
# 1190           Your Highness          21596445           28013733
# 1191         Youth in Revolt          15281286           19651093
# 1192        Zero Dark Thirty          95720716          132820716
# 1193  Zombieland: Double Tap          73123082          122810399
# 1194               Zookeeper          80360843          169852759
#
#                             Distributor  Opening_weekend_box  \
# 0              Fox Searchlight Pictures               923715
# 1              Fox Searchlight Pictures               264851
# 2                    Paramount Pictures             16194738
# 3                    Universal Pictures               576216
# 4                    Universal Pictures             27059130
# ...                                 ...                  ...
# 1190                 Universal Pictures              9360020
# 1191                    Dimension Films              6888334
# 1192  Sony Pictures Entertainment (SPE)               417150
# 1193  Sony Pictures Entertainment (SPE)             26803104
# 1194  Sony Pictures Entertainment (SPE)             20065617
#
#       no_Theaters_open    Budget                             Genre  \
# 0                   19  20000000           Biography,Drama,History
# 1                    4  18000000                   Biography,Drama
# 2                 2389  50000000         Action,Drama,Thriller,War
# 3                   11  95000000                  Action,Drama,War
# 4                 3025  61000000      Action,Comedy,Crime,Thriller
# ...                ...       ...                               ...
# 1190              2769  49900000  Adventure,Comedy,Fantasy,Romance
# 1191              1873  18000000              Comedy,Drama,Romance
# 1192                 5  40000000        Drama,History,Thriller,War
# 1193              3468  42000000              Action,Comedy,Horror
# 1194              3482  80000000     Comedy,Family,Fantasy,Romance
#
#       Days_In_theaters  Running_Time(min)  G  PG  PG_13  R  winter  spring  \
# 0                  440                134  0   0      0  1       0       0
# 1                  422                 94  0   0      0  1       0       0
# 2                  352                144  0   0      0  1       1       0
# 3                  373                119  0   0      0  1       0       0
# 4                  152                109  0   0      0  1       0       0
# ...                ...                ... ..  ..    ... ..     ...     ...
# 1190               268                102  0   0      0  1       0       1
# 1191               358                 90  0   0      0  1       1       0
# 1192               378                157  0   0      0  1       0       0
# 1193               441                 99  0   0      0  1       0       0
# 1194               177                102  0   1      0  0       0       0
#
#       summer  fall_holiday  Genre Label
# 0          0             1          241
# 1          0             1          235
# 2          0             0          132
# 3          0             1          133
# 4          1             0           91
# ...      ...           ...          ...
# 1190       0             0          199
# 1191       0             0          280
# 1192       0             1          346
# 1193       0             1           97
# 1194       1             0          289
#
# [1156 rows x 19 columns]

# %%
df_2.to_csv('movie_features.csv')
